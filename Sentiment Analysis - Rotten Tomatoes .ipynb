# %% [markdown]
# # Introdução
#
# A proposta desse notebook é realizar um experimento de análise de sentimentos sobre os reviews de filmes do Rotten Tomatoes. Seguirei a metodologia proposta no notebook anteriormente enviado, mas durante a execução optei por fazer pequenas modificações em relação as tecnologias.
#
# ## Preparação do dataset
#
# A primeira etapa é fazer a leitura dos arquivos contendo os textos do review e carregar os dados em estruturas do numpy, tornando assim mais fácil trabalhar com outras ferramentas como os classificadores e os pré-processadores.

# %%
import numpy as np
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer

tokenizer = RegexpTokenizer(r'[a-zA-Z0-9_]{2,}') #Only alphanumeric with size >= 2
stemmer = PorterStemmer()
    
def apply_stemming(text):
        
    stemmings = []

    for word in tokenizer.tokenize(text):
        stemmings.append(stemmer.stem(word))

    return " ".join(stemmings)
    
def load_dataset():
    neg_file = open("rt-polarity/rt-polarity.neg")
    pos_file = open("rt-polarity/rt-polarity.pos")
    
    reviews = []
    stemmed_reviews = []
    labels = []
    
    def add_review(review):
        cleaned_review = review.rstrip()
        reviews.append(cleaned_review)
        stemmed_reviews.append(apply_stemming(cleaned_review))
                
    for neg_review in neg_file:
        add_review(neg_review)
        labels.append(0)
        
    for pos_review in pos_file:
        add_review(pos_review)
        labels.append(1)
    
    return np.array(reviews), np.array(stemmed_reviews), np.array(labels)

reviews, stemmed_reviews, labels = load_dataset()

# %% [markdown]
# Um detalhe importante é que o stemming já é realizado na etapa leitura, deixando o dataset com stemming aplicado pré-processado. Optei for fazer dessa forma, pois o processo de stemming é pesado e isso facilitou o desenvolvimento das demais etapas do experimento.
#
# ### Separação em folds
#
# Para podermos fazer um teste-t pareado, optei por separar os folds do conjunto no início. Adicionando uma coluna com os folds ao dataset, é possível re-utilizar essa divisão em vários experimentos.

# %%
from sklearn.model_selection import StratifiedKFold

def prepare_datase(reviews, stemmed_reviews, labels):
    
    skf = StratifiedKFold(n_splits=10,shuffle=True)
    skf.get_n_splits(reviews, labels)

    folds = np.zeros(len(labels), dtype=np.int)
    num_fold = 1

    for train_set, test_set in skf.split(reviews, labels):
    
        for index in test_set:
            folds[index] = num_fold
    
        num_fold += 1
        
    return np.vstack((reviews, stemmed_reviews, labels, folds)).T
    
dataset = prepare_datase(reviews, stemmed_reviews, labels)

# %% [markdown]
# Com os folds separados, um método simples permite obter conjuntos de treino e teste para validação cruzada.

# %%
def split_data(dataset, fold):

    validation = dataset[dataset[:,3] == fold]
    training = dataset[dataset[:,3] != fold]
    
    return (validation, training)

# %% [markdown]
# ### Definição do vocabulário
#
# Como optei for fazer a validação cruzada manualamente, é interessante termos definido o vocabulário do dataset. Lembrando que é necessário obter vocabulário da versão com stemming e sem stemming, já que a ideia do stemming é justamente criar um vocabulário reduzido.
#
# A última etapa é construir os vetores de características para entrada nos classificadores.

# %%
def get_vocabulary(raw_text):

    vocabulary = set()
    
    for review in raw_text:

        for word in tokenizer.tokenize(review):
            vocabulary |= set(tokenizer.tokenize(review))
    
    return vocabulary

vocabulary_original = get_vocabulary(dataset[:,0])
vocabulary_stemmed = get_vocabulary(dataset[:,1])

# %% [markdown]
# ### Transformação de textos em vetor de características
#
# O scikit-learn oferece ferramentas para transformação de texto em representação do tipo bag-of-wods, no método abaixo as ferramentas do scikit-learn foram encapsuladas para gerarem os vetores de características de acordo com os experimentos propostos.
#
# O método aceita as seguintes opções:
#
# * `stemming`: booleano indicando se deve usar vocabulário com ou sem aplicação de stemming
# * `representation_type`: indica se será utilizado a contagem de palavras (`"count"`), presença de palavras (`"binary"`) ou representação TF-IDF (`"tf-idf"`).
# * `stop_words`: identifica se as stop words serão removidos na representação ou não.
# * `n_gram` = quantidade de n-gramas utilizado na representação.

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def to_bag_of_words(raw_text, stemming, representation_type, stop_words, n_gram=1):
    
    use_stop_words = "english" if stop_words else None
    vocabulary = vocabulary_stemmed if stemming else vocabulary_original
    
    if representation_type == 'binary':
        vectorizer = CountVectorizer(ngram_range=(1, n_gram), binary=True, analyzer='word', vocabulary=vocabulary, stop_words=use_stop_words)
    elif representation_type == 'count':
        vectorizer = CountVectorizer(ngram_range=(1, n_gram), binary=False, analyzer='word', vocabulary=vocabulary, stop_words=use_stop_words)
    elif representation_type == 'tf-idf':
        vectorizer = TfidfVectorizer(ngram_range=(1, n_gram), analyzer='word', vocabulary=vocabulary, stop_words=use_stop_words)
    
    return vectorizer.fit_transform(raw_text)

# %% [markdown]
# ## Execução dos algoritmos
#
# Para validar os algoritmos, fiz um "grid-search" considerando as alterações no tipo de representação e pré-processamentos. Alterações nos parâmetros dos algoritmos, como por exemplo o parâmetro $ C $ do SVM poderiam ser incluídos nessa etapa.
#
# Ao final de cada processamento, os resultados de cada fold são armazenados em uma mapa.

# %%
from sklearn import svm
from sklearn import naive_bayes
from sklearn import metrics

classifiers = {"naive_bayes": {"multinomial": naive_bayes.MultinomialNB(),
                               "bernoulli": naive_bayes.BernoulliNB(),
                               "gaussian": naive_bayes.GaussianNB()},
               "SVM": svm.LinearSVC()}
results = {}

teste = 0

for name_classifier, classifier in classifiers.items():
    
    name_key = name_classifier + "_"
    
    for stemming in [False, True]:

        stemming_key = name_key + str(stemming) + "_"
        
        for stop_words in [False, True]:

            stop_key = stemming_key + str(stop_words) + "_"

            for representation in ['binary', 'count', 'tf-idf']:

                representation_key = stop_key + representation + "_"

                for ngrams in [1, 2, 3]:

                    ngram_key = representation_key + str(ngrams)
                    results[ngram_key] = []

                    for fold in range(1,11):

                        validation, training = split_data(dataset, str(fold))
                        text_column = 1 if stemming else 0
                        
                        X_validation = to_bag_of_words(validation[:,text_column], stemming, representation, stop_words, ngrams)
                        X_training = to_bag_of_words(training[:,text_column], stemming, representation, stop_words, ngrams)

                        if name_classifier == "SVM":
                            
                            classifier.fit(X_training, training[:,2])
                            predictions = classifier.predict(X_validation)
                            
                        elif name_classifier == "naive_bayes":
                            
                            if representation == 'binary':
                                nb_classifier = classifier["bernoulli"]
                                nb_classifier.fit(X_training, training[:,2])
                            elif representation == 'count':
                                nb_classifier = classifier["multinomial"]
                                nb_classifier.fit(X_training, training[:,2])
                            elif representation == 'tf-idf':
                                nb_classifier = classifier["multinomial"]
                                nb_classifier.fit(X_training, training[:,2])
                            
                            
                            predictions = nb_classifier.predict(X_validation)
                            
                        accuracy = metrics.accuracy_score(validation[:,2], predictions)
                        results[ngram_key].append(accuracy)

                        print(f"Classifier: {name_classifier} Representation: {representation} n-grams: {ngrams} fold: {fold} stopwords: {stop_words} stemming: {stemming}: {accuracy}")
# Out:
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 1 stopwords: False stemming: False: 0.795880149812734
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 2 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 3 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 4 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 5 stopwords: False stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 6 stopwords: False stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 7 stopwords: False stemming: False: 0.7917448405253283
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 8 stopwords: False stemming: False: 0.7664165103189493
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 9 stopwords: False stemming: False: 0.7823639774859287
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 10 stopwords: False stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 1 stopwords: False stemming: False: 0.795880149812734
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 2 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 3 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 4 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 5 stopwords: False stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 6 stopwords: False stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 7 stopwords: False stemming: False: 0.7917448405253283
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 8 stopwords: False stemming: False: 0.7664165103189493
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 9 stopwords: False stemming: False: 0.7823639774859287
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 10 stopwords: False stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 1 stopwords: False stemming: False: 0.795880149812734
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 2 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 3 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 4 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 5 stopwords: False stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 6 stopwords: False stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 7 stopwords: False stemming: False: 0.7917448405253283
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 8 stopwords: False stemming: False: 0.7664165103189493
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 9 stopwords: False stemming: False: 0.7823639774859287
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 10 stopwords: False stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 1 stopwords: False stemming: False: 0.798689138576779
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 2 stopwords: False stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 3 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 4 stopwords: False stemming: False: 0.7814258911819888
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 5 stopwords: False stemming: False: 0.7607879924953096
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 6 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 7 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 8 stopwords: False stemming: False: 0.7626641651031895
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 9 stopwords: False stemming: False: 0.7823639774859287
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 10 stopwords: False stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 1 stopwords: False stemming: False: 0.798689138576779
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 2 stopwords: False stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 3 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 4 stopwords: False stemming: False: 0.7814258911819888
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 5 stopwords: False stemming: False: 0.7607879924953096
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 6 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 7 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 8 stopwords: False stemming: False: 0.7626641651031895
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 9 stopwords: False stemming: False: 0.7823639774859287
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 10 stopwords: False stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 1 stopwords: False stemming: False: 0.798689138576779
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 2 stopwords: False stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 3 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 4 stopwords: False stemming: False: 0.7814258911819888
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 5 stopwords: False stemming: False: 0.7607879924953096
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 6 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 7 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 8 stopwords: False stemming: False: 0.7626641651031895
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 9 stopwords: False stemming: False: 0.7823639774859287
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 10 stopwords: False stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 1 stopwords: False stemming: False: 0.7921348314606742
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 2 stopwords: False stemming: False: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 3 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 4 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 5 stopwords: False stemming: False: 0.773921200750469
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 6 stopwords: False stemming: False: 0.7851782363977486
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 7 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 8 stopwords: False stemming: False: 0.773921200750469
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 9 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 10 stopwords: False stemming: False: 0.7776735459662288
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 1 stopwords: False stemming: False: 0.7921348314606742
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 2 stopwords: False stemming: False: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 3 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 4 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 5 stopwords: False stemming: False: 0.773921200750469
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 6 stopwords: False stemming: False: 0.7851782363977486
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 7 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 8 stopwords: False stemming: False: 0.773921200750469
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 9 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 10 stopwords: False stemming: False: 0.7776735459662288
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 1 stopwords: False stemming: False: 0.7921348314606742
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 2 stopwords: False stemming: False: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 3 stopwords: False stemming: False: 0.776735459662289
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 4 stopwords: False stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 5 stopwords: False stemming: False: 0.773921200750469
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 6 stopwords: False stemming: False: 0.7851782363977486
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 7 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 8 stopwords: False stemming: False: 0.773921200750469
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 9 stopwords: False stemming: False: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 10 stopwords: False stemming: False: 0.7776735459662288
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 1 stopwords: True stemming: False: 0.795880149812734
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 2 stopwords: True stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 3 stopwords: True stemming: False: 0.7579737335834896
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 4 stopwords: True stemming: False: 0.7617260787992496
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 5 stopwords: True stemming: False: 0.7457786116322702
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 6 stopwords: True stemming: False: 0.775797373358349
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 7 stopwords: True stemming: False: 0.7673545966228893
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 8 stopwords: True stemming: False: 0.7626641651031895
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 9 stopwords: True stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 10 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 1 stopwords: True stemming: False: 0.795880149812734
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 2 stopwords: True stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 3 stopwords: True stemming: False: 0.7579737335834896
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 4 stopwords: True stemming: False: 0.7617260787992496
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 5 stopwords: True stemming: False: 0.7457786116322702
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 6 stopwords: True stemming: False: 0.775797373358349
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 7 stopwords: True stemming: False: 0.7673545966228893
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 8 stopwords: True stemming: False: 0.7626641651031895
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 9 stopwords: True stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 10 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 1 stopwords: True stemming: False: 0.795880149812734
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 2 stopwords: True stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 3 stopwords: True stemming: False: 0.7579737335834896
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 4 stopwords: True stemming: False: 0.7617260787992496
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 5 stopwords: True stemming: False: 0.7457786116322702
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 6 stopwords: True stemming: False: 0.775797373358349
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 7 stopwords: True stemming: False: 0.7673545966228893
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 8 stopwords: True stemming: False: 0.7626641651031895
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 9 stopwords: True stemming: False: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 10 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 1 stopwords: True stemming: False: 0.7883895131086143
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 2 stopwords: True stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 3 stopwords: True stemming: False: 0.7589118198874296
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 4 stopwords: True stemming: False: 0.7589118198874296
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 5 stopwords: True stemming: False: 0.7467166979362101
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 6 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 7 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 8 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 9 stopwords: True stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 10 stopwords: True stemming: False: 0.7598499061913696
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 1 stopwords: True stemming: False: 0.7883895131086143
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 2 stopwords: True stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 3 stopwords: True stemming: False: 0.7589118198874296
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 4 stopwords: True stemming: False: 0.7589118198874296
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 5 stopwords: True stemming: False: 0.7467166979362101
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 6 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 7 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 8 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 9 stopwords: True stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 10 stopwords: True stemming: False: 0.7598499061913696
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 1 stopwords: True stemming: False: 0.7883895131086143
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 2 stopwords: True stemming: False: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 3 stopwords: True stemming: False: 0.7589118198874296
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 4 stopwords: True stemming: False: 0.7589118198874296
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 5 stopwords: True stemming: False: 0.7467166979362101
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 6 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 7 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 8 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 9 stopwords: True stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 10 stopwords: True stemming: False: 0.7598499061913696
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 1 stopwords: True stemming: False: 0.7827715355805244
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 2 stopwords: True stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 3 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 4 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 5 stopwords: True stemming: False: 0.7579737335834896
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 6 stopwords: True stemming: False: 0.7692307692307693
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 7 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 8 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 9 stopwords: True stemming: False: 0.7701688555347092
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 10 stopwords: True stemming: False: 0.7645403377110694
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 1 stopwords: True stemming: False: 0.7827715355805244
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 2 stopwords: True stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 3 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 4 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 5 stopwords: True stemming: False: 0.7579737335834896
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 6 stopwords: True stemming: False: 0.7692307692307693
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 7 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 8 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 9 stopwords: True stemming: False: 0.7701688555347092
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 10 stopwords: True stemming: False: 0.7645403377110694
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 1 stopwords: True stemming: False: 0.7827715355805244
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 2 stopwords: True stemming: False: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 3 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 4 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 5 stopwords: True stemming: False: 0.7579737335834896
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 6 stopwords: True stemming: False: 0.7692307692307693
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 7 stopwords: True stemming: False: 0.7636022514071295
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 8 stopwords: True stemming: False: 0.7682926829268293
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 9 stopwords: True stemming: False: 0.7701688555347092
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 10 stopwords: True stemming: False: 0.7645403377110694
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 1 stopwords: False stemming: True: 0.8061797752808989
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 2 stopwords: False stemming: True: 0.7636022514071295
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 3 stopwords: False stemming: True: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 4 stopwords: False stemming: True: 0.7908067542213884
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 5 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 6 stopwords: False stemming: True: 0.7851782363977486
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 7 stopwords: False stemming: True: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 8 stopwords: False stemming: True: 0.7598499061913696
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 9 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 10 stopwords: False stemming: True: 0.773921200750469
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 1 stopwords: False stemming: True: 0.8061797752808989
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 2 stopwords: False stemming: True: 0.7636022514071295
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 3 stopwords: False stemming: True: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 4 stopwords: False stemming: True: 0.7908067542213884
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 5 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 6 stopwords: False stemming: True: 0.7851782363977486
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 7 stopwords: False stemming: True: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 8 stopwords: False stemming: True: 0.7598499061913696
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 9 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 10 stopwords: False stemming: True: 0.773921200750469
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 1 stopwords: False stemming: True: 0.8061797752808989
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 2 stopwords: False stemming: True: 0.7636022514071295
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 3 stopwords: False stemming: True: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 4 stopwords: False stemming: True: 0.7908067542213884
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 5 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 6 stopwords: False stemming: True: 0.7851782363977486
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 7 stopwords: False stemming: True: 0.7795497185741088
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 8 stopwords: False stemming: True: 0.7598499061913696
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 9 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 10 stopwords: False stemming: True: 0.773921200750469
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 1 stopwords: False stemming: True: 0.8071161048689138
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 2 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 3 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 4 stopwords: False stemming: True: 0.7823639774859287
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 5 stopwords: False stemming: True: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 6 stopwords: False stemming: True: 0.7842401500938087
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 7 stopwords: False stemming: True: 0.7814258911819888
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 8 stopwords: False stemming: True: 0.7598499061913696
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 9 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 10 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 1 stopwords: False stemming: True: 0.8071161048689138
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 2 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 3 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 4 stopwords: False stemming: True: 0.7823639774859287
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 5 stopwords: False stemming: True: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 6 stopwords: False stemming: True: 0.7842401500938087
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 7 stopwords: False stemming: True: 0.7814258911819888
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 8 stopwords: False stemming: True: 0.7598499061913696
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 9 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 10 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 1 stopwords: False stemming: True: 0.8071161048689138
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 2 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 3 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 4 stopwords: False stemming: True: 0.7823639774859287
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 5 stopwords: False stemming: True: 0.7729831144465291
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 6 stopwords: False stemming: True: 0.7842401500938087
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 7 stopwords: False stemming: True: 0.7814258911819888
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 8 stopwords: False stemming: True: 0.7598499061913696
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 9 stopwords: False stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 10 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 1 stopwords: False stemming: True: 0.8071161048689138
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 2 stopwords: False stemming: True: 0.7692307692307693
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 3 stopwords: False stemming: True: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 4 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 5 stopwords: False stemming: True: 0.7795497185741088
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 6 stopwords: False stemming: True: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 7 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 8 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 9 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 10 stopwords: False stemming: True: 0.776735459662289
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 1 stopwords: False stemming: True: 0.8071161048689138
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 2 stopwords: False stemming: True: 0.7692307692307693
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 3 stopwords: False stemming: True: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 4 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 5 stopwords: False stemming: True: 0.7795497185741088
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 6 stopwords: False stemming: True: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 7 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 8 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 9 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 10 stopwords: False stemming: True: 0.776735459662289
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 1 stopwords: False stemming: True: 0.8071161048689138
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 2 stopwords: False stemming: True: 0.7692307692307693
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 3 stopwords: False stemming: True: 0.7786116322701688
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 4 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 5 stopwords: False stemming: True: 0.7795497185741088
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 6 stopwords: False stemming: True: 0.7889305816135085
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 7 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 8 stopwords: False stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 9 stopwords: False stemming: True: 0.7804878048780488
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 10 stopwords: False stemming: True: 0.776735459662289
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 1 stopwords: True stemming: True: 0.7893258426966292
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 2 stopwords: True stemming: True: 0.7617260787992496
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 3 stopwords: True stemming: True: 0.7532833020637899
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 4 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 5 stopwords: True stemming: True: 0.7607879924953096
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 6 stopwords: True stemming: True: 0.7851782363977486
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 7 stopwords: True stemming: True: 0.775797373358349
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 8 stopwords: True stemming: True: 0.7626641651031895
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 9 stopwords: True stemming: True: 0.7673545966228893
# Classifier: naive_bayes Representation: binary n-grams: 1 fold: 10 stopwords: True stemming: True: 0.7720450281425891
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 1 stopwords: True stemming: True: 0.7893258426966292
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 2 stopwords: True stemming: True: 0.7617260787992496
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 3 stopwords: True stemming: True: 0.7532833020637899
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 4 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 5 stopwords: True stemming: True: 0.7607879924953096
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 6 stopwords: True stemming: True: 0.7851782363977486
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 7 stopwords: True stemming: True: 0.775797373358349
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 8 stopwords: True stemming: True: 0.7626641651031895
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 9 stopwords: True stemming: True: 0.7673545966228893
# Classifier: naive_bayes Representation: binary n-grams: 2 fold: 10 stopwords: True stemming: True: 0.7720450281425891
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 1 stopwords: True stemming: True: 0.7893258426966292
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 2 stopwords: True stemming: True: 0.7617260787992496
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 3 stopwords: True stemming: True: 0.7532833020637899
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 4 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 5 stopwords: True stemming: True: 0.7607879924953096
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 6 stopwords: True stemming: True: 0.7851782363977486
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 7 stopwords: True stemming: True: 0.775797373358349
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 8 stopwords: True stemming: True: 0.7626641651031895
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 9 stopwords: True stemming: True: 0.7673545966228893
# Classifier: naive_bayes Representation: binary n-grams: 3 fold: 10 stopwords: True stemming: True: 0.7720450281425891
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 1 stopwords: True stemming: True: 0.7874531835205992
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 2 stopwords: True stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 3 stopwords: True stemming: True: 0.7495309568480301
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 4 stopwords: True stemming: True: 0.7673545966228893
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 5 stopwords: True stemming: True: 0.7560975609756098
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 6 stopwords: True stemming: True: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 7 stopwords: True stemming: True: 0.7720450281425891
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 8 stopwords: True stemming: True: 0.7617260787992496
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 9 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: count n-grams: 1 fold: 10 stopwords: True stemming: True: 0.7664165103189493
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 1 stopwords: True stemming: True: 0.7874531835205992
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 2 stopwords: True stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 3 stopwords: True stemming: True: 0.7495309568480301
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 4 stopwords: True stemming: True: 0.7673545966228893
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 5 stopwords: True stemming: True: 0.7560975609756098
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 6 stopwords: True stemming: True: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 7 stopwords: True stemming: True: 0.7720450281425891
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 8 stopwords: True stemming: True: 0.7617260787992496
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 9 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: count n-grams: 2 fold: 10 stopwords: True stemming: True: 0.7664165103189493
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 1 stopwords: True stemming: True: 0.7874531835205992
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 2 stopwords: True stemming: True: 0.7711069418386491
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 3 stopwords: True stemming: True: 0.7495309568480301
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 4 stopwords: True stemming: True: 0.7673545966228893
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 5 stopwords: True stemming: True: 0.7560975609756098
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 6 stopwords: True stemming: True: 0.7786116322701688
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 7 stopwords: True stemming: True: 0.7720450281425891
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 8 stopwords: True stemming: True: 0.7617260787992496
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 9 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: count n-grams: 3 fold: 10 stopwords: True stemming: True: 0.7664165103189493
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 1 stopwords: True stemming: True: 0.7911985018726592
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 2 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 3 stopwords: True stemming: True: 0.7579737335834896
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 4 stopwords: True stemming: True: 0.7701688555347092
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 5 stopwords: True stemming: True: 0.7570356472795498
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 6 stopwords: True stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 7 stopwords: True stemming: True: 0.774859287054409
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 8 stopwords: True stemming: True: 0.7664165103189493
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 9 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: tf-idf n-grams: 1 fold: 10 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 1 stopwords: True stemming: True: 0.7911985018726592
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 2 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 3 stopwords: True stemming: True: 0.7579737335834896
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 4 stopwords: True stemming: True: 0.7701688555347092
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 5 stopwords: True stemming: True: 0.7570356472795498
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 6 stopwords: True stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 7 stopwords: True stemming: True: 0.774859287054409
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 8 stopwords: True stemming: True: 0.7664165103189493
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 9 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: tf-idf n-grams: 2 fold: 10 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 1 stopwords: True stemming: True: 0.7911985018726592
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 2 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 3 stopwords: True stemming: True: 0.7579737335834896
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 4 stopwords: True stemming: True: 0.7701688555347092
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 5 stopwords: True stemming: True: 0.7570356472795498
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 6 stopwords: True stemming: True: 0.7776735459662288
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 7 stopwords: True stemming: True: 0.774859287054409
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 8 stopwords: True stemming: True: 0.7664165103189493
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 9 stopwords: True stemming: True: 0.7654784240150094
# Classifier: naive_bayes Representation: tf-idf n-grams: 3 fold: 10 stopwords: True stemming: True: 0.7654784240150094
# Classifier: SVM Representation: binary n-grams: 1 fold: 1 stopwords: False stemming: False: 0.7546816479400749
# Classifier: SVM Representation: binary n-grams: 1 fold: 2 stopwords: False stemming: False: 0.7504690431519699
# Classifier: SVM Representation: binary n-grams: 1 fold: 3 stopwords: False stemming: False: 0.7495309568480301
# Classifier: SVM Representation: binary n-grams: 1 fold: 4 stopwords: False stemming: False: 0.7636022514071295
# Classifier: SVM Representation: binary n-grams: 1 fold: 5 stopwords: False stemming: False: 0.7636022514071295
# Classifier: SVM Representation: binary n-grams: 1 fold: 6 stopwords: False stemming: False: 0.7476547842401501
# Classifier: SVM Representation: binary n-grams: 1 fold: 7 stopwords: False stemming: False: 0.7560975609756098
# Classifier: SVM Representation: binary n-grams: 1 fold: 8 stopwords: False stemming: False: 0.7448405253283302
# Classifier: SVM Representation: binary n-grams: 1 fold: 9 stopwords: False stemming: False: 0.7373358348968105
# Classifier: SVM Representation: binary n-grams: 1 fold: 10 stopwords: False stemming: False: 0.7448405253283302
# Classifier: SVM Representation: binary n-grams: 2 fold: 1 stopwords: False stemming: False: 0.7546816479400749
# Classifier: SVM Representation: binary n-grams: 2 fold: 2 stopwords: False stemming: False: 0.7504690431519699
# Classifier: SVM Representation: binary n-grams: 2 fold: 3 stopwords: False stemming: False: 0.7495309568480301
# Classifier: SVM Representation: binary n-grams: 2 fold: 4 stopwords: False stemming: False: 0.7636022514071295
# Classifier: SVM Representation: binary n-grams: 2 fold: 5 stopwords: False stemming: False: 0.7636022514071295
# Classifier: SVM Representation: binary n-grams: 2 fold: 6 stopwords: False stemming: False: 0.7476547842401501
# Classifier: SVM Representation: binary n-grams: 2 fold: 7 stopwords: False stemming: False: 0.7560975609756098
# Classifier: SVM Representation: binary n-grams: 2 fold: 8 stopwords: False stemming: False: 0.7448405253283302
# Classifier: SVM Representation: binary n-grams: 2 fold: 9 stopwords: False stemming: False: 0.7373358348968105
# Classifier: SVM Representation: binary n-grams: 2 fold: 10 stopwords: False stemming: False: 0.7448405253283302
# Classifier: SVM Representation: binary n-grams: 3 fold: 1 stopwords: False stemming: False: 0.7546816479400749
# Classifier: SVM Representation: binary n-grams: 3 fold: 2 stopwords: False stemming: False: 0.7504690431519699
# Classifier: SVM Representation: binary n-grams: 3 fold: 3 stopwords: False stemming: False: 0.7495309568480301
# Classifier: SVM Representation: binary n-grams: 3 fold: 4 stopwords: False stemming: False: 0.7636022514071295
# Classifier: SVM Representation: binary n-grams: 3 fold: 5 stopwords: False stemming: False: 0.7636022514071295
# Classifier: SVM Representation: binary n-grams: 3 fold: 6 stopwords: False stemming: False: 0.7476547842401501
# Classifier: SVM Representation: binary n-grams: 3 fold: 7 stopwords: False stemming: False: 0.7560975609756098
# Classifier: SVM Representation: binary n-grams: 3 fold: 8 stopwords: False stemming: False: 0.7448405253283302
# Classifier: SVM Representation: binary n-grams: 3 fold: 9 stopwords: False stemming: False: 0.7373358348968105
# Classifier: SVM Representation: binary n-grams: 3 fold: 10 stopwords: False stemming: False: 0.7448405253283302
# Classifier: SVM Representation: count n-grams: 1 fold: 1 stopwords: False stemming: False: 0.7612359550561798
# Classifier: SVM Representation: count n-grams: 1 fold: 2 stopwords: False stemming: False: 0.7485928705440901
# Classifier: SVM Representation: count n-grams: 1 fold: 3 stopwords: False stemming: False: 0.7570356472795498
# Classifier: SVM Representation: count n-grams: 1 fold: 4 stopwords: False stemming: False: 0.7617260787992496
# Classifier: SVM Representation: count n-grams: 1 fold: 5 stopwords: False stemming: False: 0.7523452157598499
# Classifier: SVM Representation: count n-grams: 1 fold: 6 stopwords: False stemming: False: 0.7467166979362101
# Classifier: SVM Representation: count n-grams: 1 fold: 7 stopwords: False stemming: False: 0.7448405253283302
# Classifier: SVM Representation: count n-grams: 1 fold: 8 stopwords: False stemming: False: 0.7335834896810507
# Classifier: SVM Representation: count n-grams: 1 fold: 9 stopwords: False stemming: False: 0.7401500938086304
# Classifier: SVM Representation: count n-grams: 1 fold: 10 stopwords: False stemming: False: 0.7514071294559099
# Classifier: SVM Representation: count n-grams: 2 fold: 1 stopwords: False stemming: False: 0.7612359550561798
# Classifier: SVM Representation: count n-grams: 2 fold: 2 stopwords: False stemming: False: 0.7485928705440901
# Classifier: SVM Representation: count n-grams: 2 fold: 3 stopwords: False stemming: False: 0.7570356472795498
# Classifier: SVM Representation: count n-grams: 2 fold: 4 stopwords: False stemming: False: 0.7617260787992496
# Classifier: SVM Representation: count n-grams: 2 fold: 5 stopwords: False stemming: False: 0.7523452157598499
# Classifier: SVM Representation: count n-grams: 2 fold: 6 stopwords: False stemming: False: 0.7467166979362101
# Classifier: SVM Representation: count n-grams: 2 fold: 7 stopwords: False stemming: False: 0.7448405253283302
# Classifier: SVM Representation: count n-grams: 2 fold: 8 stopwords: False stemming: False: 0.7335834896810507
# Classifier: SVM Representation: count n-grams: 2 fold: 9 stopwords: False stemming: False: 0.7401500938086304
# Classifier: SVM Representation: count n-grams: 2 fold: 10 stopwords: False stemming: False: 0.7514071294559099
# Classifier: SVM Representation: count n-grams: 3 fold: 1 stopwords: False stemming: False: 0.7612359550561798
# ...
# Classifier: SVM Representation: count n-grams: 1 fold: 5 stopwords: False stemming: True: 0.7392120075046904
# Classifier: SVM Representation: count n-grams: 1 fold: 6 stopwords: False stemming: True: 0.7392120075046904
# Classifier: SVM Representation: count n-grams: 1 fold: 7 stopwords: False stemming: True: 0.7448405253283302
# Classifier: SVM Representation: count n-grams: 1 fold: 8 stopwords: False stemming: True: 0.7457786116322702
# Classifier: SVM Representation: count n-grams: 1 fold: 9 stopwords: False stemming: True: 0.7354596622889306
# Classifier: SVM Representation: count n-grams: 1 fold: 10 stopwords: False stemming: True: 0.7298311444652908
# Classifier: SVM Representation: count n-grams: 2 fold: 1 stopwords: False stemming: True: 0.7631086142322098
# Classifier: SVM Representation: count n-grams: 2 fold: 2 stopwords: False stemming: True: 0.7429643527204502
# Classifier: SVM Representation: count n-grams: 2 fold: 3 stopwords: False stemming: True: 0.7279549718574109
# Classifier: SVM Representation: count n-grams: 2 fold: 4 stopwords: False stemming: True: 0.7570356472795498
# Classifier: SVM Representation: count n-grams: 2 fold: 5 stopwords: False stemming: True: 0.7392120075046904
# Classifier: SVM Representation: count n-grams: 2 fold: 6 stopwords: False stemming: True: 0.7392120075046904
# Classifier: SVM Representation: count n-grams: 2 fold: 7 stopwords: False stemming: True: 0.7448405253283302
# Classifier: SVM Representation: count n-grams: 2 fold: 8 stopwords: False stemming: True: 0.7457786116322702
# Classifier: SVM Representation: count n-grams: 2 fold: 9 stopwords: False stemming: True: 0.7354596622889306
# Classifier: SVM Representation: count n-grams: 2 fold: 10 stopwords: False stemming: True: 0.7298311444652908
# Classifier: SVM Representation: count n-grams: 3 fold: 1 stopwords: False stemming: True: 0.7631086142322098
# Classifier: SVM Representation: count n-grams: 3 fold: 2 stopwords: False stemming: True: 0.7429643527204502
# Classifier: SVM Representation: count n-grams: 3 fold: 3 stopwords: False stemming: True: 0.7279549718574109
# Classifier: SVM Representation: count n-grams: 3 fold: 4 stopwords: False stemming: True: 0.7570356472795498
# Classifier: SVM Representation: count n-grams: 3 fold: 5 stopwords: False stemming: True: 0.7392120075046904
# Classifier: SVM Representation: count n-grams: 3 fold: 6 stopwords: False stemming: True: 0.7392120075046904
# Classifier: SVM Representation: count n-grams: 3 fold: 7 stopwords: False stemming: True: 0.7448405253283302
# Classifier: SVM Representation: count n-grams: 3 fold: 8 stopwords: False stemming: True: 0.7457786116322702
# Classifier: SVM Representation: count n-grams: 3 fold: 9 stopwords: False stemming: True: 0.7354596622889306
# Classifier: SVM Representation: count n-grams: 3 fold: 10 stopwords: False stemming: True: 0.7298311444652908
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 1 stopwords: False stemming: True: 0.7818352059925093
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 2 stopwords: False stemming: True: 0.7654784240150094
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 3 stopwords: False stemming: True: 0.7720450281425891
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 4 stopwords: False stemming: True: 0.774859287054409
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 5 stopwords: False stemming: True: 0.7645403377110694
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 6 stopwords: False stemming: True: 0.7626641651031895
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 7 stopwords: False stemming: True: 0.7692307692307693
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 8 stopwords: False stemming: True: 0.7579737335834896
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 9 stopwords: False stemming: True: 0.7664165103189493
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 10 stopwords: False stemming: True: 0.7532833020637899
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 1 stopwords: False stemming: True: 0.7818352059925093
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 2 stopwords: False stemming: True: 0.7654784240150094
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 3 stopwords: False stemming: True: 0.7720450281425891
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 4 stopwords: False stemming: True: 0.774859287054409
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 5 stopwords: False stemming: True: 0.7645403377110694
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 6 stopwords: False stemming: True: 0.7626641651031895
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 7 stopwords: False stemming: True: 0.7692307692307693
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 8 stopwords: False stemming: True: 0.7579737335834896
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 9 stopwords: False stemming: True: 0.7664165103189493
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 10 stopwords: False stemming: True: 0.7532833020637899
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 1 stopwords: False stemming: True: 0.7818352059925093
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 2 stopwords: False stemming: True: 0.7654784240150094
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 3 stopwords: False stemming: True: 0.7720450281425891
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 4 stopwords: False stemming: True: 0.774859287054409
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 5 stopwords: False stemming: True: 0.7645403377110694
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 6 stopwords: False stemming: True: 0.7626641651031895
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 7 stopwords: False stemming: True: 0.7692307692307693
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 8 stopwords: False stemming: True: 0.7579737335834896
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 9 stopwords: False stemming: True: 0.7664165103189493
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 10 stopwords: False stemming: True: 0.7532833020637899
# Classifier: SVM Representation: binary n-grams: 1 fold: 1 stopwords: True stemming: True: 0.7387640449438202
# Classifier: SVM Representation: binary n-grams: 1 fold: 2 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: binary n-grams: 1 fold: 3 stopwords: True stemming: True: 0.7063789868667918
# Classifier: SVM Representation: binary n-grams: 1 fold: 4 stopwords: True stemming: True: 0.7345215759849906
# Classifier: SVM Representation: binary n-grams: 1 fold: 5 stopwords: True stemming: True: 0.723264540337711
# Classifier: SVM Representation: binary n-grams: 1 fold: 6 stopwords: True stemming: True: 0.7195121951219512
# Classifier: SVM Representation: binary n-grams: 1 fold: 7 stopwords: True stemming: True: 0.7185741088180112
# Classifier: SVM Representation: binary n-grams: 1 fold: 8 stopwords: True stemming: True: 0.7373358348968105
# Classifier: SVM Representation: binary n-grams: 1 fold: 9 stopwords: True stemming: True: 0.7279549718574109
# Classifier: SVM Representation: binary n-grams: 1 fold: 10 stopwords: True stemming: True: 0.7166979362101313
# Classifier: SVM Representation: binary n-grams: 2 fold: 1 stopwords: True stemming: True: 0.7387640449438202
# Classifier: SVM Representation: binary n-grams: 2 fold: 2 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: binary n-grams: 2 fold: 3 stopwords: True stemming: True: 0.7063789868667918
# Classifier: SVM Representation: binary n-grams: 2 fold: 4 stopwords: True stemming: True: 0.7345215759849906
# Classifier: SVM Representation: binary n-grams: 2 fold: 5 stopwords: True stemming: True: 0.723264540337711
# Classifier: SVM Representation: binary n-grams: 2 fold: 6 stopwords: True stemming: True: 0.7195121951219512
# Classifier: SVM Representation: binary n-grams: 2 fold: 7 stopwords: True stemming: True: 0.7185741088180112
# Classifier: SVM Representation: binary n-grams: 2 fold: 8 stopwords: True stemming: True: 0.7373358348968105
# Classifier: SVM Representation: binary n-grams: 2 fold: 9 stopwords: True stemming: True: 0.7279549718574109
# Classifier: SVM Representation: binary n-grams: 2 fold: 10 stopwords: True stemming: True: 0.7166979362101313
# Classifier: SVM Representation: binary n-grams: 3 fold: 1 stopwords: True stemming: True: 0.7387640449438202
# Classifier: SVM Representation: binary n-grams: 3 fold: 2 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: binary n-grams: 3 fold: 3 stopwords: True stemming: True: 0.7063789868667918
# Classifier: SVM Representation: binary n-grams: 3 fold: 4 stopwords: True stemming: True: 0.7345215759849906
# Classifier: SVM Representation: binary n-grams: 3 fold: 5 stopwords: True stemming: True: 0.723264540337711
# Classifier: SVM Representation: binary n-grams: 3 fold: 6 stopwords: True stemming: True: 0.7195121951219512
# Classifier: SVM Representation: binary n-grams: 3 fold: 7 stopwords: True stemming: True: 0.7185741088180112
# Classifier: SVM Representation: binary n-grams: 3 fold: 8 stopwords: True stemming: True: 0.7373358348968105
# Classifier: SVM Representation: binary n-grams: 3 fold: 9 stopwords: True stemming: True: 0.7279549718574109
# Classifier: SVM Representation: binary n-grams: 3 fold: 10 stopwords: True stemming: True: 0.7166979362101313
# Classifier: SVM Representation: count n-grams: 1 fold: 1 stopwords: True stemming: True: 0.7397003745318352
# Classifier: SVM Representation: count n-grams: 1 fold: 2 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: count n-grams: 1 fold: 3 stopwords: True stemming: True: 0.7120075046904315
# Classifier: SVM Representation: count n-grams: 1 fold: 4 stopwords: True stemming: True: 0.7288930581613509
# Classifier: SVM Representation: count n-grams: 1 fold: 5 stopwords: True stemming: True: 0.7288930581613509
# Classifier: SVM Representation: count n-grams: 1 fold: 6 stopwords: True stemming: True: 0.723264540337711
# Classifier: SVM Representation: count n-grams: 1 fold: 7 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: count n-grams: 1 fold: 8 stopwords: True stemming: True: 0.7401500938086304
# Classifier: SVM Representation: count n-grams: 1 fold: 9 stopwords: True stemming: True: 0.7335834896810507
# Classifier: SVM Representation: count n-grams: 1 fold: 10 stopwords: True stemming: True: 0.7063789868667918
# Classifier: SVM Representation: count n-grams: 2 fold: 1 stopwords: True stemming: True: 0.7397003745318352
# Classifier: SVM Representation: count n-grams: 2 fold: 2 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: count n-grams: 2 fold: 3 stopwords: True stemming: True: 0.7120075046904315
# Classifier: SVM Representation: count n-grams: 2 fold: 4 stopwords: True stemming: True: 0.7288930581613509
# Classifier: SVM Representation: count n-grams: 2 fold: 5 stopwords: True stemming: True: 0.7288930581613509
# Classifier: SVM Representation: count n-grams: 2 fold: 6 stopwords: True stemming: True: 0.723264540337711
# Classifier: SVM Representation: count n-grams: 2 fold: 7 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: count n-grams: 2 fold: 8 stopwords: True stemming: True: 0.7401500938086304
# Classifier: SVM Representation: count n-grams: 2 fold: 9 stopwords: True stemming: True: 0.7335834896810507
# Classifier: SVM Representation: count n-grams: 2 fold: 10 stopwords: True stemming: True: 0.7063789868667918
# Classifier: SVM Representation: count n-grams: 3 fold: 1 stopwords: True stemming: True: 0.7397003745318352
# Classifier: SVM Representation: count n-grams: 3 fold: 2 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: count n-grams: 3 fold: 3 stopwords: True stemming: True: 0.7120075046904315
# Classifier: SVM Representation: count n-grams: 3 fold: 4 stopwords: True stemming: True: 0.7288930581613509
# Classifier: SVM Representation: count n-grams: 3 fold: 5 stopwords: True stemming: True: 0.7288930581613509
# Classifier: SVM Representation: count n-grams: 3 fold: 6 stopwords: True stemming: True: 0.723264540337711
# Classifier: SVM Representation: count n-grams: 3 fold: 7 stopwords: True stemming: True: 0.7204502814258912
# Classifier: SVM Representation: count n-grams: 3 fold: 8 stopwords: True stemming: True: 0.7401500938086304
# Classifier: SVM Representation: count n-grams: 3 fold: 9 stopwords: True stemming: True: 0.7335834896810507
# Classifier: SVM Representation: count n-grams: 3 fold: 10 stopwords: True stemming: True: 0.7063789868667918
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 1 stopwords: True stemming: True: 0.7818352059925093
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 2 stopwords: True stemming: True: 0.7392120075046904
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 3 stopwords: True stemming: True: 0.7345215759849906
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 4 stopwords: True stemming: True: 0.7448405253283302
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 5 stopwords: True stemming: True: 0.7495309568480301
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 6 stopwords: True stemming: True: 0.7476547842401501
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 7 stopwords: True stemming: True: 0.7401500938086304
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 8 stopwords: True stemming: True: 0.7607879924953096
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 9 stopwords: True stemming: True: 0.7551594746716698
# Classifier: SVM Representation: tf-idf n-grams: 1 fold: 10 stopwords: True stemming: True: 0.7467166979362101
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 1 stopwords: True stemming: True: 0.7818352059925093
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 2 stopwords: True stemming: True: 0.7392120075046904
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 3 stopwords: True stemming: True: 0.7345215759849906
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 4 stopwords: True stemming: True: 0.7448405253283302
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 5 stopwords: True stemming: True: 0.7495309568480301
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 6 stopwords: True stemming: True: 0.7476547842401501
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 7 stopwords: True stemming: True: 0.7401500938086304
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 8 stopwords: True stemming: True: 0.7607879924953096
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 9 stopwords: True stemming: True: 0.7551594746716698
# Classifier: SVM Representation: tf-idf n-grams: 2 fold: 10 stopwords: True stemming: True: 0.7467166979362101
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 1 stopwords: True stemming: True: 0.7818352059925093
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 2 stopwords: True stemming: True: 0.7392120075046904
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 3 stopwords: True stemming: True: 0.7345215759849906
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 4 stopwords: True stemming: True: 0.7448405253283302
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 5 stopwords: True stemming: True: 0.7495309568480301
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 6 stopwords: True stemming: True: 0.7476547842401501
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 7 stopwords: True stemming: True: 0.7401500938086304
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 8 stopwords: True stemming: True: 0.7607879924953096
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 9 stopwords: True stemming: True: 0.7551594746716698
# Classifier: SVM Representation: tf-idf n-grams: 3 fold: 10 stopwords: True stemming: True: 0.7467166979362101

# %% [markdown]
# Algo interessante a observar é que o Naive Bayes multinomial funciona com  representação TF-IDF, inicialmente testei com [Naive Bayes Gaussiano](http://scikit-learn.org/stable/modules/naive_bayes.html#gaussian-naive-bayes) pelo TF-IDF ser uma representação de dados contínua, mas obtive péssimos resultados. Aparentemente, é implementada uma solução que adapta o [algoritmo multinomial ao TF-IDF](http://www.cs.waikato.ac.nz/ml/publications/2004/kibriya_et_al_cr.pdf).
#
# ## Validação dos resultados
#
# Na metodologia, apontei que faria a validação dos resultados usando o R, msa para manter tudo em apenas um notebook achei mais simples seguir com Pyhton usando o scipy e pandas para as validações necessárias.
#
# Abaixo, criei um DataFrame montando um cartesiano entre as execuções, contabilizando a média de acurácia de cada algoritmo e calculando o teste-t para verificar se as médias são diferentes.

# %%
from scipy import stats
import pandas as pd

def tabulate_results(results):
    
    processed_pairs = set()
    
    col_combination_1 = []
    col_combination_2 = []
    col_accuracy_1 = []
    col_accuracy_2 = []
    col_p_test = []

    for combination_1, accuracy_1 in results.items():
        for combination_2, accuracy_2 in results.items():
    
            if combination_1 == combination_2 or combination_2 + "|" + combination_1 in processed_pairs:
                continue
            
            accuracy_avg_1 = sum(accuracy_1)/len(accuracy_1)
            accuracy_avg_2 = sum(accuracy_2)/len(accuracy_2)
            
            processed_pairs.add(combination_2 + "|" + combination_1)
            
            col_combination_1.append(combination_1)
            col_combination_2.append(combination_2)
            col_accuracy_1.append(accuracy_avg_1)
            col_accuracy_2.append(accuracy_avg_2)
            col_p_test.append(stats.ttest_rel(accuracy_1,accuracy_2))
    
    return pd.DataFrame({"combination_1": col_combination_1,
                         "combination_2": col_combination_2,
                         "accuracy_1": col_accuracy_1,
                         "accuracy_2": col_accuracy_2,
                         "p_test": col_p_test})

tabulated_results = tabulate_results(results)

# %% [markdown]
# ### Encontrando os melhores algoritmos
#
# Para encontrar as melhores combinações de algoirtmos, ordenei o data_frame criado peloa média de acurácia dos algoritmos. Dessa forma, os melhores algoritmos ficarão no topo.
#
# À primeira vista, podemos avaliar que o Naive Bayes obteve bons resultados, com variação desprezível entre os diferentes tipos de representação e pré-processamento. Além disso, o uso de $ n-gram > 1 $ não pareceu trazer ganhos na classificação também.

# %%
tabulated_results.sort_values(['accuracy_1', 'accuracy_2'], ascending=[0, 0])
# Out:
#       accuracy_1  accuracy_2                     combination_1  \
# 432     0.781653    0.781653  naive_bayes_False_False_tf-idf_1
# 433     0.781653    0.781653  naive_bayes_False_False_tf-idf_1
# 503     0.781653    0.781653  naive_bayes_False_False_tf-idf_2
# 504     0.781653    0.781653  naive_bayes_False_False_tf-idf_2
# 574     0.781653    0.781653  naive_bayes_False_False_tf-idf_3
# 575     0.781653    0.781653  naive_bayes_False_False_tf-idf_3
# 449     0.781653    0.781274  naive_bayes_False_False_tf-idf_1
# 450     0.781653    0.781274  naive_bayes_False_False_tf-idf_1
# 451     0.781653    0.781274  naive_bayes_False_False_tf-idf_1
# 520     0.781653    0.781274  naive_bayes_False_False_tf-idf_2
# 521     0.781653    0.781274  naive_bayes_False_False_tf-idf_2
# 522     0.781653    0.781274  naive_bayes_False_False_tf-idf_2
# 591     0.781653    0.781274  naive_bayes_False_False_tf-idf_3
# 592     0.781653    0.781274  naive_bayes_False_False_tf-idf_3
# 593     0.781653    0.781274  naive_bayes_False_False_tf-idf_3
# 426     0.781653    0.779494  naive_bayes_False_False_tf-idf_1
# 427     0.781653    0.779494  naive_bayes_False_False_tf-idf_1
# 428     0.781653    0.779494  naive_bayes_False_False_tf-idf_1
# 497     0.781653    0.779494  naive_bayes_False_False_tf-idf_2
# 498     0.781653    0.779494  naive_bayes_False_False_tf-idf_2
# 499     0.781653    0.779494  naive_bayes_False_False_tf-idf_2
# 568     0.781653    0.779494  naive_bayes_False_False_tf-idf_3
# 569     0.781653    0.779494  naive_bayes_False_False_tf-idf_3
# 570     0.781653    0.779494  naive_bayes_False_False_tf-idf_3
# 446     0.781653    0.778554  naive_bayes_False_False_tf-idf_1
# 447     0.781653    0.778554  naive_bayes_False_False_tf-idf_1
# 448     0.781653    0.778554  naive_bayes_False_False_tf-idf_1
# 517     0.781653    0.778554  naive_bayes_False_False_tf-idf_2
# 518     0.781653    0.778554  naive_bayes_False_False_tf-idf_2
# 519     0.781653    0.778554  naive_bayes_False_False_tf-idf_2
# ...          ...         ...                               ...
# 4592    0.724345    0.738227            SVM_True_True_binary_2
# 4593    0.724345    0.738227            SVM_True_True_binary_2
# 4594    0.724345    0.738227            SVM_True_True_binary_2
# 4663    0.724345    0.738227            SVM_True_True_binary_3
# 4664    0.724345    0.738227            SVM_True_True_binary_3
# 4665    0.724345    0.738227            SVM_True_True_binary_3
# 4518    0.724345    0.737289            SVM_True_True_binary_1
# 4519    0.724345    0.737289            SVM_True_True_binary_1
# 4520    0.724345    0.737289            SVM_True_True_binary_1
# 4589    0.724345    0.737289            SVM_True_True_binary_2
# 4590    0.724345    0.737289            SVM_True_True_binary_2
# 4591    0.724345    0.737289            SVM_True_True_binary_2
# 4660    0.724345    0.737289            SVM_True_True_binary_3
# 4661    0.724345    0.737289            SVM_True_True_binary_3
# 4662    0.724345    0.737289            SVM_True_True_binary_3
# 4538    0.724345    0.725377            SVM_True_True_binary_1
# 4539    0.724345    0.725377            SVM_True_True_binary_1
# 4540    0.724345    0.725377            SVM_True_True_binary_1
# 4609    0.724345    0.725377            SVM_True_True_binary_2
# 4610    0.724345    0.725377            SVM_True_True_binary_2
# 4611    0.724345    0.725377            SVM_True_True_binary_2
# 4680    0.724345    0.725377            SVM_True_True_binary_3
# 4681    0.724345    0.725377            SVM_True_True_binary_3
# 4682    0.724345    0.725377            SVM_True_True_binary_3
# 4536    0.724345    0.724345            SVM_True_True_binary_1
# 4537    0.724345    0.724345            SVM_True_True_binary_1
# 4607    0.724345    0.724345            SVM_True_True_binary_2
# 4608    0.724345    0.724345            SVM_True_True_binary_2
# 4678    0.724345    0.724345            SVM_True_True_binary_3
# 4679    0.724345    0.724345            SVM_True_True_binary_3
#
#                          combination_2                              p_test
# 432   naive_bayes_False_False_tf-idf_2                          (nan, nan)
# 433   naive_bayes_False_False_tf-idf_3                          (nan, nan)
# 503   naive_bayes_False_False_tf-idf_1                          (nan, nan)
# 504   naive_bayes_False_False_tf-idf_3                          (nan, nan)
# 574   naive_bayes_False_False_tf-idf_1                          (nan, nan)
# 575   naive_bayes_False_False_tf-idf_2                          (nan, nan)
# 449    naive_bayes_True_False_tf-idf_1    (0.152388667931, 0.882241989021)
# 450    naive_bayes_True_False_tf-idf_2    (0.152388667931, 0.882241989021)
# 451    naive_bayes_True_False_tf-idf_3    (0.152388667931, 0.882241989021)
# 520    naive_bayes_True_False_tf-idf_1    (0.152388667931, 0.882241989021)
# 521    naive_bayes_True_False_tf-idf_2    (0.152388667931, 0.882241989021)
# 522    naive_bayes_True_False_tf-idf_3    (0.152388667931, 0.882241989021)
# 591    naive_bayes_True_False_tf-idf_1    (0.152388667931, 0.882241989021)
# 592    naive_bayes_True_False_tf-idf_2    (0.152388667931, 0.882241989021)
# 593    naive_bayes_True_False_tf-idf_3    (0.152388667931, 0.882241989021)
# 426   naive_bayes_False_False_binary_1     (1.08591736837, 0.305743555608)
# 427   naive_bayes_False_False_binary_2     (1.08591736837, 0.305743555608)
# 428   naive_bayes_False_False_binary_3     (1.08591736837, 0.305743555608)
# 497   naive_bayes_False_False_binary_1     (1.08591736837, 0.305743555608)
# 498   naive_bayes_False_False_binary_2     (1.08591736837, 0.305743555608)
# 499   naive_bayes_False_False_binary_3     (1.08591736837, 0.305743555608)
# 568   naive_bayes_False_False_binary_1     (1.08591736837, 0.305743555608)
# 569   naive_bayes_False_False_binary_2     (1.08591736837, 0.305743555608)
# 570   naive_bayes_False_False_binary_3     (1.08591736837, 0.305743555608)
# 446     naive_bayes_True_False_count_1      (1.1465295189, 0.281143241949)
# 447     naive_bayes_True_False_count_2      (1.1465295189, 0.281143241949)
# 448     naive_bayes_True_False_count_3      (1.1465295189, 0.281143241949)
# 517     naive_bayes_True_False_count_1      (1.1465295189, 0.281143241949)
# 518     naive_bayes_True_False_count_2      (1.1465295189, 0.281143241949)
# 519     naive_bayes_True_False_count_3      (1.1465295189, 0.281143241949)
# ...                                ...                                 ...
# 4592            SVM_False_True_count_1  (-4.72245378788, 0.00108534039404)
# 4593            SVM_False_True_count_2  (-4.72245378788, 0.00108534039404)
# 4594            SVM_False_True_count_3  (-4.72245378788, 0.00108534039404)
# 4663            SVM_False_True_count_1  (-4.72245378788, 0.00108534039404)
# 4664            SVM_False_True_count_2  (-4.72245378788, 0.00108534039404)
# 4665            SVM_False_True_count_3  (-4.72245378788, 0.00108534039404)
# 4518           SVM_False_True_binary_1  (-3.42846000805, 0.00752654628299)
# 4519           SVM_False_True_binary_2  (-3.42846000805, 0.00752654628299)
# 4520           SVM_False_True_binary_3  (-3.42846000805, 0.00752654628299)
# 4589           SVM_False_True_binary_1  (-3.42846000805, 0.00752654628299)
# 4590           SVM_False_True_binary_2  (-3.42846000805, 0.00752654628299)
# 4591           SVM_False_True_binary_3  (-3.42846000805, 0.00752654628299)
# 4660           SVM_False_True_binary_1  (-3.42846000805, 0.00752654628299)
# 4661           SVM_False_True_binary_2  (-3.42846000805, 0.00752654628299)
# 4662           SVM_False_True_binary_3  (-3.42846000805, 0.00752654628299)
# 4538             SVM_True_True_count_1    (-0.62033064299, 0.550422716952)
# 4539             SVM_True_True_count_2    (-0.62033064299, 0.550422716952)
# 4540             SVM_True_True_count_3    (-0.62033064299, 0.550422716952)
# 4609             SVM_True_True_count_1    (-0.62033064299, 0.550422716952)
# 4610             SVM_True_True_count_2    (-0.62033064299, 0.550422716952)
# 4611             SVM_True_True_count_3    (-0.62033064299, 0.550422716952)
# 4680             SVM_True_True_count_1    (-0.62033064299, 0.550422716952)
# 4681             SVM_True_True_count_2    (-0.62033064299, 0.550422716952)
# 4682             SVM_True_True_count_3    (-0.62033064299, 0.550422716952)
# 4536            SVM_True_True_binary_2                          (nan, nan)
# 4537            SVM_True_True_binary_3                          (nan, nan)
# 4607            SVM_True_True_binary_1                          (nan, nan)
# 4608            SVM_True_True_binary_3                          (nan, nan)
# 4678            SVM_True_True_binary_1                          (nan, nan)
# 4679            SVM_True_True_binary_2                          (nan, nan)
#
# [5112 rows x 5 columns]

# %% [markdown]
# Para confirmar se as variações do Naive Bayes não foram relevantes, vamos verificar a maior diferença de média entre diferente configurações do algoritmo. Nesse caso, vemos que a contagem tem um desempenho signigificativamente pior que usando representação TF-IDF, enquanto o uso de representação binária mantém o mesmo desempenho do TF-IDF.

# %%
tabulated_results[tabulated_results.combination_2.str.startswith('naive_bayes')].sort_values(['accuracy_1', 'accuracy_2'], ascending=[0, 1])
# Out:
#       accuracy_1  accuracy_2                     combination_1  \
# 437     0.781653    0.766456  naive_bayes_False_False_tf-idf_1
# 438     0.781653    0.766456  naive_bayes_False_False_tf-idf_1
# 439     0.781653    0.766456  naive_bayes_False_False_tf-idf_1
# 508     0.781653    0.766456  naive_bayes_False_False_tf-idf_2
# 509     0.781653    0.766456  naive_bayes_False_False_tf-idf_2
# 510     0.781653    0.766456  naive_bayes_False_False_tf-idf_2
# 579     0.781653    0.766456  naive_bayes_False_False_tf-idf_3
# 580     0.781653    0.766456  naive_bayes_False_False_tf-idf_3
# 581     0.781653    0.766456  naive_bayes_False_False_tf-idf_3
# 455     0.781653    0.767582  naive_bayes_False_False_tf-idf_1
# 456     0.781653    0.767582  naive_bayes_False_False_tf-idf_1
# 457     0.781653    0.767582  naive_bayes_False_False_tf-idf_1
# 526     0.781653    0.767582  naive_bayes_False_False_tf-idf_2
# 527     0.781653    0.767582  naive_bayes_False_False_tf-idf_2
# 528     0.781653    0.767582  naive_bayes_False_False_tf-idf_2
# 597     0.781653    0.767582  naive_bayes_False_False_tf-idf_3
# 598     0.781653    0.767582  naive_bayes_False_False_tf-idf_3
# 599     0.781653    0.767582  naive_bayes_False_False_tf-idf_3
# 440     0.781653    0.768240  naive_bayes_False_False_tf-idf_1
# 441     0.781653    0.768240  naive_bayes_False_False_tf-idf_1
# 442     0.781653    0.768240  naive_bayes_False_False_tf-idf_1
# 511     0.781653    0.768240  naive_bayes_False_False_tf-idf_2
# 512     0.781653    0.768240  naive_bayes_False_False_tf-idf_2
# 513     0.781653    0.768240  naive_bayes_False_False_tf-idf_2
# 582     0.781653    0.768240  naive_bayes_False_False_tf-idf_3
# 583     0.781653    0.768240  naive_bayes_False_False_tf-idf_3
# 584     0.781653    0.768240  naive_bayes_False_False_tf-idf_3
# 434     0.781653    0.768800  naive_bayes_False_False_tf-idf_1
# 435     0.781653    0.768800  naive_bayes_False_False_tf-idf_1
# 436     0.781653    0.768800  naive_bayes_False_False_tf-idf_1
# ...          ...         ...                               ...
# 4636    0.724345    0.778554            SVM_True_True_binary_3
# 4637    0.724345    0.778554            SVM_True_True_binary_3
# 4638    0.724345    0.778554            SVM_True_True_binary_3
# 4473    0.724345    0.779494            SVM_True_True_binary_1
# 4474    0.724345    0.779494            SVM_True_True_binary_1
# 4475    0.724345    0.779494            SVM_True_True_binary_1
# 4544    0.724345    0.779494            SVM_True_True_binary_2
# 4545    0.724345    0.779494            SVM_True_True_binary_2
# 4546    0.724345    0.779494            SVM_True_True_binary_2
# 4615    0.724345    0.779494            SVM_True_True_binary_3
# 4616    0.724345    0.779494            SVM_True_True_binary_3
# 4617    0.724345    0.779494            SVM_True_True_binary_3
# 4497    0.724345    0.781274            SVM_True_True_binary_1
# 4498    0.724345    0.781274            SVM_True_True_binary_1
# 4499    0.724345    0.781274            SVM_True_True_binary_1
# 4568    0.724345    0.781274            SVM_True_True_binary_2
# 4569    0.724345    0.781274            SVM_True_True_binary_2
# 4570    0.724345    0.781274            SVM_True_True_binary_2
# 4639    0.724345    0.781274            SVM_True_True_binary_3
# 4640    0.724345    0.781274            SVM_True_True_binary_3
# 4641    0.724345    0.781274            SVM_True_True_binary_3
# 4479    0.724345    0.781653            SVM_True_True_binary_1
# 4480    0.724345    0.781653            SVM_True_True_binary_1
# 4481    0.724345    0.781653            SVM_True_True_binary_1
# 4550    0.724345    0.781653            SVM_True_True_binary_2
# 4551    0.724345    0.781653            SVM_True_True_binary_2
# 4552    0.724345    0.781653            SVM_True_True_binary_2
# 4621    0.724345    0.781653            SVM_True_True_binary_3
# 4622    0.724345    0.781653            SVM_True_True_binary_3
# 4623    0.724345    0.781653            SVM_True_True_binary_3
#
#                          combination_2                               p_test
# 437     naive_bayes_False_True_count_1   (6.80649592923, 7.84776011779e-05)
# 438     naive_bayes_False_True_count_2   (6.80649592923, 7.84776011779e-05)
# 439     naive_bayes_False_True_count_3   (6.80649592923, 7.84776011779e-05)
# 508     naive_bayes_False_True_count_1   (6.80649592923, 7.84776011779e-05)
# 509     naive_bayes_False_True_count_2   (6.80649592923, 7.84776011779e-05)
# 510     naive_bayes_False_True_count_3   (6.80649592923, 7.84776011779e-05)
# 579     naive_bayes_False_True_count_1   (6.80649592923, 7.84776011779e-05)
# 580     naive_bayes_False_True_count_2   (6.80649592923, 7.84776011779e-05)
# 581     naive_bayes_False_True_count_3   (6.80649592923, 7.84776011779e-05)
# 455      naive_bayes_True_True_count_1   (6.16812451128, 0.000165073579029)
# 456      naive_bayes_True_True_count_2   (6.16812451128, 0.000165073579029)
# 457      naive_bayes_True_True_count_3   (6.16812451128, 0.000165073579029)
# 526      naive_bayes_True_True_count_1   (6.16812451128, 0.000165073579029)
# 527      naive_bayes_True_True_count_2   (6.16812451128, 0.000165073579029)
# 528      naive_bayes_True_True_count_3   (6.16812451128, 0.000165073579029)
# 597      naive_bayes_True_True_count_1   (6.16812451128, 0.000165073579029)
# 598      naive_bayes_True_True_count_2   (6.16812451128, 0.000165073579029)
# 599      naive_bayes_True_True_count_3   (6.16812451128, 0.000165073579029)
# 440    naive_bayes_False_True_tf-idf_1    (6.39246080528, 0.00012638816157)
# 441    naive_bayes_False_True_tf-idf_2    (6.39246080528, 0.00012638816157)
# 442    naive_bayes_False_True_tf-idf_3    (6.39246080528, 0.00012638816157)
# 511    naive_bayes_False_True_tf-idf_1    (6.39246080528, 0.00012638816157)
# 512    naive_bayes_False_True_tf-idf_2    (6.39246080528, 0.00012638816157)
# 513    naive_bayes_False_True_tf-idf_3    (6.39246080528, 0.00012638816157)
# 582    naive_bayes_False_True_tf-idf_1    (6.39246080528, 0.00012638816157)
# 583    naive_bayes_False_True_tf-idf_2    (6.39246080528, 0.00012638816157)
# 584    naive_bayes_False_True_tf-idf_3    (6.39246080528, 0.00012638816157)
# 434    naive_bayes_False_True_binary_1    (4.59584524743, 0.00129817801867)
# 435    naive_bayes_False_True_binary_2    (4.59584524743, 0.00129817801867)
# 436    naive_bayes_False_True_binary_3    (4.59584524743, 0.00129817801867)
# ...                                ...                                  ...
# 4636    naive_bayes_True_False_count_1  (-12.2051687804, 6.66364498032e-07)
# 4637    naive_bayes_True_False_count_2  (-12.2051687804, 6.66364498032e-07)
# 4638    naive_bayes_True_False_count_3  (-12.2051687804, 6.66364498032e-07)
# 4473  naive_bayes_False_False_binary_1   (-13.5701718473, 2.6840968575e-07)
# 4474  naive_bayes_False_False_binary_2   (-13.5701718473, 2.6840968575e-07)
# 4475  naive_bayes_False_False_binary_3   (-13.5701718473, 2.6840968575e-07)
# 4544  naive_bayes_False_False_binary_1   (-13.5701718473, 2.6840968575e-07)
# 4545  naive_bayes_False_False_binary_2   (-13.5701718473, 2.6840968575e-07)
# 4546  naive_bayes_False_False_binary_3   (-13.5701718473, 2.6840968575e-07)
# 4615  naive_bayes_False_False_binary_1   (-13.5701718473, 2.6840968575e-07)
# 4616  naive_bayes_False_False_binary_2   (-13.5701718473, 2.6840968575e-07)
# 4617  naive_bayes_False_False_binary_3   (-13.5701718473, 2.6840968575e-07)
# 4497   naive_bayes_True_False_tf-idf_1  (-14.9917506353, 1.13350481993e-07)
# 4498   naive_bayes_True_False_tf-idf_2  (-14.9917506353, 1.13350481993e-07)
# 4499   naive_bayes_True_False_tf-idf_3  (-14.9917506353, 1.13350481993e-07)
# 4568   naive_bayes_True_False_tf-idf_1  (-14.9917506353, 1.13350481993e-07)
# 4569   naive_bayes_True_False_tf-idf_2  (-14.9917506353, 1.13350481993e-07)
# 4570   naive_bayes_True_False_tf-idf_3  (-14.9917506353, 1.13350481993e-07)
# 4639   naive_bayes_True_False_tf-idf_1  (-14.9917506353, 1.13350481993e-07)
# 4640   naive_bayes_True_False_tf-idf_2  (-14.9917506353, 1.13350481993e-07)
# 4641   naive_bayes_True_False_tf-idf_3  (-14.9917506353, 1.13350481993e-07)
# 4479  naive_bayes_False_False_tf-idf_1  (-16.3281987635, 5.38800101534e-08)
# 4480  naive_bayes_False_False_tf-idf_2  (-16.3281987635, 5.38800101534e-08)
# 4481  naive_bayes_False_False_tf-idf_3  (-16.3281987635, 5.38800101534e-08)
# 4550  naive_bayes_False_False_tf-idf_1  (-16.3281987635, 5.38800101534e-08)
# 4551  naive_bayes_False_False_tf-idf_2  (-16.3281987635, 5.38800101534e-08)
# 4552  naive_bayes_False_False_tf-idf_3  (-16.3281987635, 5.38800101534e-08)
# 4621  naive_bayes_False_False_tf-idf_1  (-16.3281987635, 5.38800101534e-08)
# 4622  naive_bayes_False_False_tf-idf_2  (-16.3281987635, 5.38800101534e-08)
# 4623  naive_bayes_False_False_tf-idf_3  (-16.3281987635, 5.38800101534e-08)
#
# [2556 rows x 5 columns]

# %% [markdown]
# Em comparação ao SVM, podemos verificar que o Naive Bayes obteve melhor desempenho mesmo contra as melhores configurações utilizadas com SVM, que teve desempenho mais próximo ao Naive Bayes utilizando contagem de palavras.
#
# Vale observar que é interessante experimentar outras configurações no algoritmo do SVM, como alterações nos fatores de penalidade e regularização, assim mesmo como utilizar outros tipo de Kernel.

# %%
tabulated_results[tabulated_results.combination_1.str.startswith('SVM')].sort_values(['accuracy_1', 'accuracy_2'], ascending=[0, 0])
# Out:
#       accuracy_1  accuracy_2             combination_1  \
# 2988    0.770211    0.781653  SVM_False_False_tf-idf_1
# 2989    0.770211    0.781653  SVM_False_False_tf-idf_1
# 2990    0.770211    0.781653  SVM_False_False_tf-idf_1
# 3059    0.770211    0.781653  SVM_False_False_tf-idf_2
# 3060    0.770211    0.781653  SVM_False_False_tf-idf_2
# 3061    0.770211    0.781653  SVM_False_False_tf-idf_2
# 3130    0.770211    0.781653  SVM_False_False_tf-idf_3
# 3131    0.770211    0.781653  SVM_False_False_tf-idf_3
# 3132    0.770211    0.781653  SVM_False_False_tf-idf_3
# 3006    0.770211    0.781274  SVM_False_False_tf-idf_1
# 3007    0.770211    0.781274  SVM_False_False_tf-idf_1
# 3008    0.770211    0.781274  SVM_False_False_tf-idf_1
# 3077    0.770211    0.781274  SVM_False_False_tf-idf_2
# 3078    0.770211    0.781274  SVM_False_False_tf-idf_2
# 3079    0.770211    0.781274  SVM_False_False_tf-idf_2
# 3148    0.770211    0.781274  SVM_False_False_tf-idf_3
# 3149    0.770211    0.781274  SVM_False_False_tf-idf_3
# 3150    0.770211    0.781274  SVM_False_False_tf-idf_3
# 2982    0.770211    0.779494  SVM_False_False_tf-idf_1
# 2983    0.770211    0.779494  SVM_False_False_tf-idf_1
# 2984    0.770211    0.779494  SVM_False_False_tf-idf_1
# 3053    0.770211    0.779494  SVM_False_False_tf-idf_2
# 3054    0.770211    0.779494  SVM_False_False_tf-idf_2
# 3055    0.770211    0.779494  SVM_False_False_tf-idf_2
# 3124    0.770211    0.779494  SVM_False_False_tf-idf_3
# 3125    0.770211    0.779494  SVM_False_False_tf-idf_3
# 3126    0.770211    0.779494  SVM_False_False_tf-idf_3
# 3003    0.770211    0.778554  SVM_False_False_tf-idf_1
# 3004    0.770211    0.778554  SVM_False_False_tf-idf_1
# 3005    0.770211    0.778554  SVM_False_False_tf-idf_1
# ...          ...         ...                       ...
# 4592    0.724345    0.738227    SVM_True_True_binary_2
# 4593    0.724345    0.738227    SVM_True_True_binary_2
# 4594    0.724345    0.738227    SVM_True_True_binary_2
# 4663    0.724345    0.738227    SVM_True_True_binary_3
# 4664    0.724345    0.738227    SVM_True_True_binary_3
# 4665    0.724345    0.738227    SVM_True_True_binary_3
# 4518    0.724345    0.737289    SVM_True_True_binary_1
# 4519    0.724345    0.737289    SVM_True_True_binary_1
# 4520    0.724345    0.737289    SVM_True_True_binary_1
# 4589    0.724345    0.737289    SVM_True_True_binary_2
# 4590    0.724345    0.737289    SVM_True_True_binary_2
# 4591    0.724345    0.737289    SVM_True_True_binary_2
# 4660    0.724345    0.737289    SVM_True_True_binary_3
# 4661    0.724345    0.737289    SVM_True_True_binary_3
# 4662    0.724345    0.737289    SVM_True_True_binary_3
# 4538    0.724345    0.725377    SVM_True_True_binary_1
# 4539    0.724345    0.725377    SVM_True_True_binary_1
# 4540    0.724345    0.725377    SVM_True_True_binary_1
# 4609    0.724345    0.725377    SVM_True_True_binary_2
# 4610    0.724345    0.725377    SVM_True_True_binary_2
# 4611    0.724345    0.725377    SVM_True_True_binary_2
# 4680    0.724345    0.725377    SVM_True_True_binary_3
# 4681    0.724345    0.725377    SVM_True_True_binary_3
# 4682    0.724345    0.725377    SVM_True_True_binary_3
# 4536    0.724345    0.724345    SVM_True_True_binary_1
# 4537    0.724345    0.724345    SVM_True_True_binary_1
# 4607    0.724345    0.724345    SVM_True_True_binary_2
# 4608    0.724345    0.724345    SVM_True_True_binary_2
# 4678    0.724345    0.724345    SVM_True_True_binary_3
# 4679    0.724345    0.724345    SVM_True_True_binary_3
#
#                          combination_2                              p_test
# 2988  naive_bayes_False_False_tf-idf_1   (-2.77613027251, 0.0215365744699)
# 2989  naive_bayes_False_False_tf-idf_2   (-2.77613027251, 0.0215365744699)
# 2990  naive_bayes_False_False_tf-idf_3   (-2.77613027251, 0.0215365744699)
# 3059  naive_bayes_False_False_tf-idf_1   (-2.77613027251, 0.0215365744699)
# 3060  naive_bayes_False_False_tf-idf_2   (-2.77613027251, 0.0215365744699)
# 3061  naive_bayes_False_False_tf-idf_3   (-2.77613027251, 0.0215365744699)
# 3130  naive_bayes_False_False_tf-idf_1   (-2.77613027251, 0.0215365744699)
# 3131  naive_bayes_False_False_tf-idf_2   (-2.77613027251, 0.0215365744699)
# 3132  naive_bayes_False_False_tf-idf_3   (-2.77613027251, 0.0215365744699)
# 3006   naive_bayes_True_False_tf-idf_1   (-2.64847613839, 0.0265424131144)
# 3007   naive_bayes_True_False_tf-idf_2   (-2.64847613839, 0.0265424131144)
# 3008   naive_bayes_True_False_tf-idf_3   (-2.64847613839, 0.0265424131144)
# 3077   naive_bayes_True_False_tf-idf_1   (-2.64847613839, 0.0265424131144)
# 3078   naive_bayes_True_False_tf-idf_2   (-2.64847613839, 0.0265424131144)
# 3079   naive_bayes_True_False_tf-idf_3   (-2.64847613839, 0.0265424131144)
# 3148   naive_bayes_True_False_tf-idf_1   (-2.64847613839, 0.0265424131144)
# 3149   naive_bayes_True_False_tf-idf_2   (-2.64847613839, 0.0265424131144)
# 3150   naive_bayes_True_False_tf-idf_3   (-2.64847613839, 0.0265424131144)
# 2982  naive_bayes_False_False_binary_1    (-2.2987882416, 0.0470926696218)
# 2983  naive_bayes_False_False_binary_2    (-2.2987882416, 0.0470926696218)
# 2984  naive_bayes_False_False_binary_3    (-2.2987882416, 0.0470926696218)
# 3053  naive_bayes_False_False_binary_1    (-2.2987882416, 0.0470926696218)
# 3054  naive_bayes_False_False_binary_2    (-2.2987882416, 0.0470926696218)
# 3055  naive_bayes_False_False_binary_3    (-2.2987882416, 0.0470926696218)
# 3124  naive_bayes_False_False_binary_1    (-2.2987882416, 0.0470926696218)
# 3125  naive_bayes_False_False_binary_2    (-2.2987882416, 0.0470926696218)
# 3126  naive_bayes_False_False_binary_3    (-2.2987882416, 0.0470926696218)
# 3003    naive_bayes_True_False_count_1   (-2.10960702648, 0.0641106689582)
# 3004    naive_bayes_True_False_count_2   (-2.10960702648, 0.0641106689582)
# 3005    naive_bayes_True_False_count_3   (-2.10960702648, 0.0641106689582)
# ...                                ...                                 ...
# 4592            SVM_False_True_count_1  (-4.72245378788, 0.00108534039404)
# 4593            SVM_False_True_count_2  (-4.72245378788, 0.00108534039404)
# 4594            SVM_False_True_count_3  (-4.72245378788, 0.00108534039404)
# 4663            SVM_False_True_count_1  (-4.72245378788, 0.00108534039404)
# 4664            SVM_False_True_count_2  (-4.72245378788, 0.00108534039404)
# 4665            SVM_False_True_count_3  (-4.72245378788, 0.00108534039404)
# 4518           SVM_False_True_binary_1  (-3.42846000805, 0.00752654628299)
# 4519           SVM_False_True_binary_2  (-3.42846000805, 0.00752654628299)
# 4520           SVM_False_True_binary_3  (-3.42846000805, 0.00752654628299)
# 4589           SVM_False_True_binary_1  (-3.42846000805, 0.00752654628299)
# 4590           SVM_False_True_binary_2  (-3.42846000805, 0.00752654628299)
# 4591           SVM_False_True_binary_3  (-3.42846000805, 0.00752654628299)
# 4660           SVM_False_True_binary_1  (-3.42846000805, 0.00752654628299)
# 4661           SVM_False_True_binary_2  (-3.42846000805, 0.00752654628299)
# 4662           SVM_False_True_binary_3  (-3.42846000805, 0.00752654628299)
# 4538             SVM_True_True_count_1    (-0.62033064299, 0.550422716952)
# 4539             SVM_True_True_count_2    (-0.62033064299, 0.550422716952)
# 4540             SVM_True_True_count_3    (-0.62033064299, 0.550422716952)
# 4609             SVM_True_True_count_1    (-0.62033064299, 0.550422716952)
# 4610             SVM_True_True_count_2    (-0.62033064299, 0.550422716952)
# 4611             SVM_True_True_count_3    (-0.62033064299, 0.550422716952)
# 4680             SVM_True_True_count_1    (-0.62033064299, 0.550422716952)
# 4681             SVM_True_True_count_2    (-0.62033064299, 0.550422716952)
# 4682             SVM_True_True_count_3    (-0.62033064299, 0.550422716952)
# 4536            SVM_True_True_binary_2                          (nan, nan)
# 4537            SVM_True_True_binary_3                          (nan, nan)
# 4607            SVM_True_True_binary_1                          (nan, nan)
# 4608            SVM_True_True_binary_3                          (nan, nan)
# 4678            SVM_True_True_binary_1                          (nan, nan)
# 4679            SVM_True_True_binary_2                          (nan, nan)
#
# [2556 rows x 5 columns]

# %% [markdown]
# Comparando o resultado das diferenças configurações do SVM, é interessante notar que a representação teve um impacto considerável na performance do algoritmo, sendo o TF-IDF novamente a melhor opção para representação.

# %%
svm_results =  tabulated_results[tabulated_results.combination_1.str.startswith('SVM')]
svm_results_only = svm_results[svm_results.combination_2.str.startswith('SVM')]
svm_results_only.sort_values(['accuracy_1', 'accuracy_2'], ascending=[0, 1])
# Out:
#       accuracy_1  accuracy_2             combination_1  \
# 3044    0.770211    0.724345  SVM_False_False_tf-idf_1
# 3045    0.770211    0.724345  SVM_False_False_tf-idf_1
# 3046    0.770211    0.724345  SVM_False_False_tf-idf_1
# 3115    0.770211    0.724345  SVM_False_False_tf-idf_2
# 3116    0.770211    0.724345  SVM_False_False_tf-idf_2
# 3117    0.770211    0.724345  SVM_False_False_tf-idf_2
# 3186    0.770211    0.724345  SVM_False_False_tf-idf_3
# 3187    0.770211    0.724345  SVM_False_False_tf-idf_3
# 3188    0.770211    0.724345  SVM_False_False_tf-idf_3
# 3047    0.770211    0.725377  SVM_False_False_tf-idf_1
# 3048    0.770211    0.725377  SVM_False_False_tf-idf_1
# 3049    0.770211    0.725377  SVM_False_False_tf-idf_1
# 3118    0.770211    0.725377  SVM_False_False_tf-idf_2
# 3119    0.770211    0.725377  SVM_False_False_tf-idf_2
# 3120    0.770211    0.725377  SVM_False_False_tf-idf_2
# 3189    0.770211    0.725377  SVM_False_False_tf-idf_3
# 3190    0.770211    0.725377  SVM_False_False_tf-idf_3
# 3191    0.770211    0.725377  SVM_False_False_tf-idf_3
# 3026    0.770211    0.737289  SVM_False_False_tf-idf_1
# 3027    0.770211    0.737289  SVM_False_False_tf-idf_1
# 3028    0.770211    0.737289  SVM_False_False_tf-idf_1
# 3097    0.770211    0.737289  SVM_False_False_tf-idf_2
# 3098    0.770211    0.737289  SVM_False_False_tf-idf_2
# 3099    0.770211    0.737289  SVM_False_False_tf-idf_2
# 3168    0.770211    0.737289  SVM_False_False_tf-idf_3
# 3169    0.770211    0.737289  SVM_False_False_tf-idf_3
# 3170    0.770211    0.737289  SVM_False_False_tf-idf_3
# 3029    0.770211    0.738227  SVM_False_False_tf-idf_1
# 3030    0.770211    0.738227  SVM_False_False_tf-idf_1
# 3031    0.770211    0.738227  SVM_False_False_tf-idf_1
# ...          ...         ...                       ...
# 4651    0.724345    0.751266    SVM_True_True_binary_3
# 4652    0.724345    0.751266    SVM_True_True_binary_3
# 4653    0.724345    0.751266    SVM_True_True_binary_3
# 4524    0.724345    0.754358    SVM_True_True_binary_1
# 4525    0.724345    0.754358    SVM_True_True_binary_1
# 4526    0.724345    0.754358    SVM_True_True_binary_1
# 4595    0.724345    0.754358    SVM_True_True_binary_2
# 4596    0.724345    0.754358    SVM_True_True_binary_2
# 4597    0.724345    0.754358    SVM_True_True_binary_2
# 4666    0.724345    0.754358    SVM_True_True_binary_3
# 4667    0.724345    0.754358    SVM_True_True_binary_3
# 4668    0.724345    0.754358    SVM_True_True_binary_3
# 4533    0.724345    0.766833    SVM_True_True_binary_1
# 4534    0.724345    0.766833    SVM_True_True_binary_1
# 4535    0.724345    0.766833    SVM_True_True_binary_1
# 4604    0.724345    0.766833    SVM_True_True_binary_2
# 4605    0.724345    0.766833    SVM_True_True_binary_2
# 4606    0.724345    0.766833    SVM_True_True_binary_2
# 4675    0.724345    0.766833    SVM_True_True_binary_3
# 4676    0.724345    0.766833    SVM_True_True_binary_3
# 4677    0.724345    0.766833    SVM_True_True_binary_3
# 4515    0.724345    0.770211    SVM_True_True_binary_1
# 4516    0.724345    0.770211    SVM_True_True_binary_1
# 4517    0.724345    0.770211    SVM_True_True_binary_1
# 4586    0.724345    0.770211    SVM_True_True_binary_2
# 4587    0.724345    0.770211    SVM_True_True_binary_2
# 4588    0.724345    0.770211    SVM_True_True_binary_2
# 4657    0.724345    0.770211    SVM_True_True_binary_3
# 4658    0.724345    0.770211    SVM_True_True_binary_3
# 4659    0.724345    0.770211    SVM_True_True_binary_3
#
#                  combination_2                               p_test
# 3044    SVM_True_True_binary_1   (8.62449229291, 1.20830590488e-05)
# 3045    SVM_True_True_binary_2   (8.62449229291, 1.20830590488e-05)
# 3046    SVM_True_True_binary_3   (8.62449229291, 1.20830590488e-05)
# 3115    SVM_True_True_binary_1   (8.62449229291, 1.20830590488e-05)
# 3116    SVM_True_True_binary_2   (8.62449229291, 1.20830590488e-05)
# 3117    SVM_True_True_binary_3   (8.62449229291, 1.20830590488e-05)
# 3186    SVM_True_True_binary_1   (8.62449229291, 1.20830590488e-05)
# 3187    SVM_True_True_binary_2   (8.62449229291, 1.20830590488e-05)
# 3188    SVM_True_True_binary_3   (8.62449229291, 1.20830590488e-05)
# 3047     SVM_True_True_count_1   (8.09509494022, 2.01382270753e-05)
# 3048     SVM_True_True_count_2   (8.09509494022, 2.01382270753e-05)
# 3049     SVM_True_True_count_3   (8.09509494022, 2.01382270753e-05)
# 3118     SVM_True_True_count_1   (8.09509494022, 2.01382270753e-05)
# 3119     SVM_True_True_count_2   (8.09509494022, 2.01382270753e-05)
# 3120     SVM_True_True_count_3   (8.09509494022, 2.01382270753e-05)
# 3189     SVM_True_True_count_1   (8.09509494022, 2.01382270753e-05)
# 3190     SVM_True_True_count_2   (8.09509494022, 2.01382270753e-05)
# 3191     SVM_True_True_count_3   (8.09509494022, 2.01382270753e-05)
# 3026   SVM_False_True_binary_1   (7.23146708656, 4.91337667991e-05)
# 3027   SVM_False_True_binary_2   (7.23146708656, 4.91337667991e-05)
# 3028   SVM_False_True_binary_3   (7.23146708656, 4.91337667991e-05)
# 3097   SVM_False_True_binary_1   (7.23146708656, 4.91337667991e-05)
# 3098   SVM_False_True_binary_2   (7.23146708656, 4.91337667991e-05)
# 3099   SVM_False_True_binary_3   (7.23146708656, 4.91337667991e-05)
# 3168   SVM_False_True_binary_1   (7.23146708656, 4.91337667991e-05)
# 3169   SVM_False_True_binary_2   (7.23146708656, 4.91337667991e-05)
# 3170   SVM_False_True_binary_3   (7.23146708656, 4.91337667991e-05)
# 3029    SVM_False_True_count_1   (5.76886354316, 0.000269814979338)
# 3030    SVM_False_True_count_2   (5.76886354316, 0.000269814979338)
# 3031    SVM_False_True_count_3   (5.76886354316, 0.000269814979338)
# ...                        ...                                  ...
# 4651  SVM_False_False_binary_1   (-6.87767798914, 7.2453239018e-05)
# 4652  SVM_False_False_binary_2   (-6.87767798914, 7.2453239018e-05)
# 4653  SVM_False_False_binary_3   (-6.87767798914, 7.2453239018e-05)
# 4524   SVM_False_True_tf-idf_1  (-6.86387263877, 7.35809373423e-05)
# 4525   SVM_False_True_tf-idf_2  (-6.86387263877, 7.35809373423e-05)
# 4526   SVM_False_True_tf-idf_3  (-6.86387263877, 7.35809373423e-05)
# 4595   SVM_False_True_tf-idf_1  (-6.86387263877, 7.35809373423e-05)
# 4596   SVM_False_True_tf-idf_2  (-6.86387263877, 7.35809373423e-05)
# 4597   SVM_False_True_tf-idf_3  (-6.86387263877, 7.35809373423e-05)
# 4666   SVM_False_True_tf-idf_1  (-6.86387263877, 7.35809373423e-05)
# 4667   SVM_False_True_tf-idf_2  (-6.86387263877, 7.35809373423e-05)
# 4668   SVM_False_True_tf-idf_3  (-6.86387263877, 7.35809373423e-05)
# 4533   SVM_True_False_tf-idf_1   (-11.9078592642, 8.2221996526e-07)
# 4534   SVM_True_False_tf-idf_2   (-11.9078592642, 8.2221996526e-07)
# 4535   SVM_True_False_tf-idf_3   (-11.9078592642, 8.2221996526e-07)
# 4604   SVM_True_False_tf-idf_1   (-11.9078592642, 8.2221996526e-07)
# 4605   SVM_True_False_tf-idf_2   (-11.9078592642, 8.2221996526e-07)
# 4606   SVM_True_False_tf-idf_3   (-11.9078592642, 8.2221996526e-07)
# 4675   SVM_True_False_tf-idf_1   (-11.9078592642, 8.2221996526e-07)
# 4676   SVM_True_False_tf-idf_2   (-11.9078592642, 8.2221996526e-07)
# 4677   SVM_True_False_tf-idf_3   (-11.9078592642, 8.2221996526e-07)
# 4515  SVM_False_False_tf-idf_1  (-8.62449229291, 1.20830590488e-05)
# 4516  SVM_False_False_tf-idf_2  (-8.62449229291, 1.20830590488e-05)
# 4517  SVM_False_False_tf-idf_3  (-8.62449229291, 1.20830590488e-05)
# 4586  SVM_False_False_tf-idf_1  (-8.62449229291, 1.20830590488e-05)
# 4587  SVM_False_False_tf-idf_2  (-8.62449229291, 1.20830590488e-05)
# 4588  SVM_False_False_tf-idf_3  (-8.62449229291, 1.20830590488e-05)
# 4657  SVM_False_False_tf-idf_1  (-8.62449229291, 1.20830590488e-05)
# 4658  SVM_False_False_tf-idf_2  (-8.62449229291, 1.20830590488e-05)
# 4659  SVM_False_False_tf-idf_3  (-8.62449229291, 1.20830590488e-05)
#
# [1260 rows x 5 columns]

# %% [markdown]
# ## Conclusão
#
# Os algoritmos tiveram performances similares, mas o Naive Bayes chegou a resultados melhores que o SVM.
#
# É interessante observar que no SVM o tipo de representação teve grande impacto, mas as demais variações não parecem ter sido muito relevantes à primeira vista nos resultados de classificação: stemming, remoção de stopwords e uso de n-gramas. Para próximos experimentos em problemas similares, talvez seja mais vantajoso trocar o foco: ao invés de investir em pré-processamento, focar em experimentar mais classificadores e alterar as configurações do mesmo.
#
# Infelizmente, faltou a implementação da solução utilizando rede neural. Talvez, seja possível obter resultados consideravelmente superiores já que estamos falando de uma abordagem completamente diferente para o problema.
#
# Para os próximos passos, seria interessante uma análise mais cuidadosa dos dados obtidos, explorar melhor o SVM e avaliar uma solução de rede neural.
